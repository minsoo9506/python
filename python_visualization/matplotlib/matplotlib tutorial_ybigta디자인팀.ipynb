# %% [markdown]
# # < matplotlib tutorial (디자인 12기 여름방학세션, 7/7) >

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
#  < 전달사항 >
# - 초반부는 그래프 그리기 & 후반부는 more 커스터마이징으로 이루어져 있음
# - 세션에 참여못한 친구들은 다소 노잼 + 노이해 일수도 있지만 현주, 소흠이는 잘할거라고 생각 ><
# - 구글링, 'matplotlib을 이용한 시각화'(도서) 등을 참고함
# - 숙제 : matplotlib.pyplot 을 이용하여 EDA 해보기 (데이터는 아무거나) -> 검사는 안하지만 코드 복붙이 아닌 자기 것으로 만들기 위해서는 꼭 하길 바람
# - 이후 21일(혜경, 민수) // 28일(지현, 현주) -> 각각 matplotlib 심화, 다양한 그래프 코딩, 꼭 matplotlib과 관련할 필요는 없지만 시각화!
# - (예를 들면, 본인은 Basemap 발제할 예정 : https://www.google.co.kr/search?q=basemap&source=lnms&tbm=isch&sa=X&ved=0ahUKEwjjqP3E5oncAhVWMt4KHfoGDGYQ_AUICigB&biw=1536&bih=759)

# %% [markdown]
# - matplotlib : https://matplotlib.org/index.html -> 무궁무진함
# - 우리가 공부하는 것은 matplotlib의 API인 pyplot
# - 각 그래프의 parameter 들은 다루지 않았는데 다음에 발제할 때 다뤄줘도 좋을듯!
#
# - x, y 에는 list 나 array가 들어감

# %% [markdown]
# # plt.plot (line plot)

# %%
# input 값이 list 형태
x = range(100)
y = [value **2 for value in x]

plt.plot(x,y)
plt.show()

# %%
# input 값이 array 형태
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
# 동시에 그래프 그리기 가능
x = np.linspace(0, 2*np.pi, 100)
ya = np.sin(x)
yb = np.cos(x)

plt.plot(x, ya)
plt.plot(x, yb)
plt.show()

# %% [markdown]
# # load file

# %%
x, y = [], []
for line in open('ex.txt','r'):
    values = [float(s) for s in line.split()]
    x.append(values[0])
    y.append(values[1])

plt.plot(x,y)
plt.show()

# %%
data = np.loadtxt('ex.txt')

plt.plot(data[:,0], data[:,1])
plt.show()

# %% [markdown]
# # scatter plot

# %%
data = np.random.rand(1024,2) # np.random.rand(a,b) -> (0,1) 사이의 값을 random으로 (a,b)의 shape 으로 array 만들어줌

plt.scatter(data[:,0], data[:,1])
plt.show()

# %% [markdown]
# # bar & barh

# %%
data = [5,25,50,20]

plt.bar(range(len(data)), data, width = 1) #width는 막대의 두께
plt.show()

# %%
plt.barh(range(len(data)), data)
plt.show()

# %%
data = [[5,10,15,20], [4,13,17,12],[6,22,14,16]]
x= np.arange(4) #array랑 range 합친 기능

plt.bar(x, data[0], color='.75', width=0.25)
plt.bar(x+0.25, data[1], color='.5', width=0.25)
plt.bar(x+0.5, data[2], color='.25', width=0.25)
plt.show()

# %%
a = [5,30,45,22]
b = [5,25,50,20]

x = range(4)

plt.figure(figsize=(3,3))
plt.bar(x, a, color = 'b')
plt.bar(x, b, color = 'r', bottom = a)
plt.show()

# %%
data = np.array([[5,30,45,22],[5,25,50,20],[1,2,1,3]])

color_list = ['b','g','r']
x = np.arange(data.shape[1])

# 그래프를 그릴 때, 함수사용하는 ><
for i in range(data.shape[0]):
    plt.bar(x, data[i], bottom = np.sum(data[:i], axis=0), color = color_list[i])
plt.show()

# %%
women_pop = np.array([5,30,45,22])
men_pop = np.array([5,25,50,20])
x = np.arange(4)

plt.barh(x, women_pop, color = 'r')
plt.barh(x, -men_pop, color = 'k')
plt.show()

# %% [markdown]
# # pie chart

# %%
slices = [7,2,2,13]
activities = ['sleeping', 'eating','working','playing']
cols = ['c','m','r','b']

# %%
plt.figure(figsize=(3,3)) #원 예쁘게 할려면 사이즈를 정사각형으로 해야됨

plt.pie(slices, labels = activities, colors = cols,
       startangle = 90, 
       explode = (0,0.1,0,0),
       autopct = '%1.1f%%') 

#startangle : 시작점 조정 
#explode : 그림처럼 원 밖으로 나오게 할 수 있음
#autopct  : 그래프 상 수치 표시 방법 조절

plt.title('interesting graph\ncheck it out')
plt.show()

# %% [markdown]
# # stack plot

# %%
days = [1,2,3,4,5]

sleeping = [7,8,6,11,7] 
eating = [2,3,4,3,2]
working = [7,8,7,2,2]
playing = [8,5,7,8,13]

# %%
plt.plot([],[],color = 'm', label = 'sleeping')
plt.plot([],[],color = 'c', label = 'eating')
plt.plot([],[],color = 'r', label = 'working')
plt.plot([],[],color = 'k', label = 'playing')
plt.stackplot(days, sleeping, eating, working, playing,
             colors = ['m','c','r','k'])

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# stackplot은 legend label 바로 못 붙임 그래서 위처럼 해야됨

# %% [markdown]
# # hist

# %%
x = np.random.randn(1000)

plt.hist(x, bins=20)
plt.show()

# %% [markdown]
# # boxplot

# %%
data = np.random.randn(100,5)

plt.boxplot(data)
plt.show()
#상자 중앙선 = 중앙값 / 상자 위아래 = 1사분위부터 3사분위까지. 데이터를 50%포함  
#위아래 뻗은 선  = 각 Q1과 Q3에 (Q3-Q1)*1.5을 빼고 더한 범위중 가장 낮은 값

# %% [markdown]
# # color 및 기타

# %%
from __future__ import division

import matplotlib.pyplot as plt
from matplotlib import colors as mcolors


colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

# Sort colors by hue, saturation, value and name.
by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                for name, color in colors.items())
sorted_names = [name for hsv, name in by_hsv]

n = len(sorted_names)
ncols = 4
nrows = n // ncols + 1

fig, ax = plt.subplots(figsize=(16, 10))

# Get height and width
X, Y = fig.get_dpi() * fig.get_size_inches()
h = Y / (nrows + 1)
w = X / ncols

for i, name in enumerate(sorted_names):
    col = i % ncols
    row = i // ncols
    y = Y - (row * h) - h

    xi_line = w * (col + 0.05)
    xf_line = w * (col + 0.25)
    xi_text = w * (col + 0.3)

    ax.text(xi_text, y, name, fontsize=(h * 0.8),
            horizontalalignment='left',
            verticalalignment='center')

    ax.hlines(y + h * 0.1, xi_line, xf_line,
              color=colors[name], linewidth=(h * 0.6))

ax.set_xlim(0, X)
ax.set_ylim(0, Y)
ax.set_axis_off()

fig.subplots_adjust(left=0, right=1,
                    top=1, bottom=0,
                    hspace=0, wspace=0)
plt.show()

# %% [markdown]
# - 위에 나오는 color 쓰면됨
# - 0.0 ~ 1.0 => 얘네는 흑백명도, 흑백 프린트 사용할 때 쓰셈

# %%
data = np.random.standard_normal((100,2))

plt.scatter(data[:,0],data[:,1], color = 'hotpink', edgecolor='1.0')
plt.show()

# %%
women_pop = np.array([5,30,45,22])
men_pop = np.array([5,25,50,20])
x = np.arange(4)

plt.barh(x, women_pop, color = '0.25')
plt.barh(x, -men_pop, color = '0.75')
plt.show()

# %%
values = np.random.random_integers(99, size = 50)

color_set = ('.00', '.25', '.5', '.75')
color_list = [color_set[(len(color_set)*val//100)] for val in values] # 높이에 따라 색을 지정하는 센스

plt.bar(np.arange(len(values)), values, color = color_list)
plt.show()
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 99 + 1) instead
#   """Entry point for launching an IPython kernel.

# %%
N = 8
a = np.random.random(N)
b = np.random.random(N)
x = np.arange(N)

plt.bar(x, a, color = '0.75')
plt.bar(x, a+b, bottom = a, color = 'w', linestyle = 'dashed') #solid, dashed, dotted, dashdot # 왜 안되지...
plt.show()

# %%
N = 8
a = np.random.random(N)
b = np.random.random(N)
x = np.arange(N)

plt.plot(x, a, linewidth = 3)
plt.plot(x, b, linewidth = 0.5)
plt.show()

# %%
N = 8
a = np.random.random(N)
b = np.random.random(N)
x = np.arange(N)

plt.bar(x, a, color = 'w', hatch = 'x')
plt.bar(x, a+b, bottom = a, color = 'w', hatch = '/')
plt.show()
# 왜 안되지 이상하네...

# %%
a = np.random.standard_normal((100,2))
a += np.array((-1,-1))

b = np.random.standard_normal((100,2))
b += np.array((1,1))

plt.scatter(a[:,0], a[:,1], color = 'k', marker = 'x')
plt.scatter(b[:,0], b[:,1], color = 'k', marker = '^')
plt.show()

# %%
a = np.random.standard_normal((100,2))
a += np.array((-1,-1))

b = np.random.standard_normal((100,2))
b += np.array((1,1))

plt.scatter(a[:,0], a[:,1], c = 'k', s = 100)
plt.scatter(b[:,0], b[:,1], c = 'b', s= 25)
plt.show()

# %% [markdown]
# # style

# %%
from matplotlib import style

# %% [markdown]
# style reference : https://matplotlib.org/examples/style_sheets/style_sheets_reference.html

# %%
print(plt.style.available)
#style.use('style') -> 하면 style 적용
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', '_classic_test']

# %% [markdown]
# # for  more customizing

# %% [markdown]
# - Figure는 그림이 그려지는 도화지 / Axes는 하나의 그래프 / Axis는 가로, 세로축을 의미

# %% [markdown]
# # Figure 객체

# %% [markdown]
# - 원래 Figure를 생성하려면 figure 명령을 사용하여 그 반환값으로 Figure 객체를 얻어야 한다. 그러나 일반적인 plot 명령 등을 실행하면 자동으로 Figure를 생성해주기 때문에 일반적으로는 figure 명령을 잘 사용하지 않는다. figure 명령을 명시적으로 사용하는 경우는 여러개의 윈도우를 동시에 띄워야 하거나, 그림의 크기를 설정하고 싶을 때이다.

# %%
np.random.seed(0)
plt.figure(figsize=(10, 2))
plt.plot(np.random.randn(100))

#style.use('fivethirtyeight')

plt.show()

# %% [markdown]
# # Axes객체와 subplot

# %%
x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)
data = np.column_stack((x, y))

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize=(8,6)) #위에서 plt.plot 하나 그릴때는 plt.figure()였음!

axes[0].scatter(x = x, y = y, edgecolor = 'k')
axes[0].set_title('first ex')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].hist(data, label = ('x','y'))
axes[1].legend(loc=(0.7,0.8))
axes[1].set_title('second ex')
axes[1].yaxis.tick_right()

plt.show()

# %%
np.random.seed(0)
# 이것처럼 subplot 으로 할거면 plt.subplot() 밑에 바로 plt.plot() 그려야 됨

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
#style.use('default') 난 걍 default가 좋아서
#plt.rcParams["figure.figsize"] = (5,3) #이거는 그냥 그래프 사이즈 defalut 조절하고 싶어서 한거 안해도 됨

import random

def creat_plots():
    xs = []
    ys = []
    
    for i in range(10):
        x = i
        y = random.randrange(10)
        
        xs.append(x)
        ys.append(y)
    return xs, ys

ax1 = plt.subplot2grid((6,1),(0,0),rowspan=1, colspan=1)
ax2 = plt.subplot2grid((6,1),(1,0),rowspan=4, colspan=1)
ax3 = plt.subplot2grid((6,1),(5,0),rowspan=1, colspan=1)
#(6,1) : 6*1 (행*열)grid 만듬 , (0,0) : 시작하는 부분
#span : 아마 차지하는 부분 표현인듯

x, y =creat_plots()
ax1.plot(x, y)
#ax1.xlabel('Air speed') -->  'AxesSubplot' object has no attribute 'xlabel' --> ax1.set_xlabel()
#ax1.ylabel('Total drag')

x, y =creat_plots()
ax2.plot(x, y)

x, y =creat_plots()
ax3.plot(x, y)

plt.show()

# %% [markdown]
# # Axis 객체와 축

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx() # twinx() : 두 그래프가 같이 x축을 사용

ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.set_xlabel('x')  # 아마 그냥 ax0.xlabel은 안될 거임 -> 그래프 하나에 해당하면 걍 xlabel해도 되는데 sublot쓰면 set_xlabel해야됨

ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")

plt.show()

# %% [markdown]
# # tick 설정

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.plot(X, C)

plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])

plt.show()

# %% [markdown]
# # title(제목 생성)

# %%
x = np.linspace(-4,4,1024)
y = .25 * (x + 4) * (x + 1) * (x - 2)

plt.title('A polynomial')

plt.plot(x, y, c = 'k')
plt.show()

# %% [markdown]
# # label(각 축에 레이블 추가)

# %%
x = np.linspace(-4,4,1024)
y = .25 * (x + 4) * (x + 1) * (x - 2)

plt.title('Power curve for airfoil KV873')

plt.xlabel('Air speed')
plt.ylabel('Total drag') 

plt.plot(x, y, c = 'k')
plt.show()

# %% [markdown]
# # 텍스트 추가

# %%
x = np.linspace(-4,4,1024)
y = .25 * (x + 4) * (x + 1) * (x - 2)

plt.text(-0.8, -0.25, 'Brackmard minimum') #앞에 숫자가 위치

plt.plot(x, y, c = 'k')
plt.show()

# %%
x = np.linspace(-4,4,1024)
y = .25 * (x + 4) * (x + 1) * (x - 2)

box = {'facecolor' : '0.75', 'edgecolor' : 'k', 'boxstyle' : 'round'}

plt.text(-0.8, -0.25, 'Brackmard minimum', bbox = box)

plt.plot(x,y, c = 'k')
plt.show()

# %%
n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

plt.figure(figsize=(10,8))

plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white', label = 'man')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white', label =  'woman')

for x,y in zip(X,Y1):
    plt.text(x, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

for x,y in zip(X,Y2):
    plt.text(x, -y-0.05, '%.2f' % y, ha='center', va= 'top')

plt.xlim(-.5,n), plt.xticks([])
plt.ylim(-1.25,+1.25), plt.yticks([])
plt.legend()

plt.show()

# %% [markdown]
# # 화살표 추가

# %%
x = np.linspace(-4,4,1024)
y = .25 * (x + 4) * (x + 1) * (x - 2)

plt.annotate('Brackmard minimum',
             ha = 'center', va = 'bottom',  # ha는 수평 va는 수직정렬 / 텍스트 상자의 어느쪽으로 정렬할지
             xytext = (-1.5, 3),            # xytext는 텍스트의 위치
             xy = (0.75, -2.7),             # 화살표의 목적지 설정
             arrowprops = {'facecolor' : 'black', 'shrink' : 0.05})

plt.plot(x,y)
plt.show()

# %% [markdown]
# # legend

# %%
x = np.linspace(0,6,1024)
y1 = np.sin(x)
y2 = np.cos(x)

plt.xlabel('x')
plt.ylabel('y')

plt.plot(x, y1, c = 'k', lw = 3, label = 'sin(x)')
plt.plot(x, y2, c = 'b', lw = 3, ls = '--', label = 'cos(x)')

plt.legend() # 파라미터 : loc(위치 : center, upper left 등) / shadow(T or F, 음영효과) / fancybox(T or F) / title / ncol

plt.show()

# %% [markdown]
# # 격자 추가

# %%
x = np.linspace(-4,4,1024)
y = .25 * (x + 4) * (x + 1) * (x - 2)

plt.plot(x, y, c = 'k')

plt.grid(True, lw = 2, ls = '--', c = '0.75')

plt.show()

# %% [markdown]
# # 모양 추가

# %%
import matplotlib.patches as patches

# 원
shape = patches.Circle((0, 0), radius = 1, color = '0.75')
plt.gca().add_patch(shape)

# 직사각형
shape = patches.Rectangle((2.5, -.5), 2, 1, color = '0.75')
plt.gca().add_patch(shape)

# 타원

shape = patches.Ellipse((0, -2), 2, 1, angle = 45, color = '0.75')
plt.gca().add_patch(shape)

plt.grid(True)
plt.axis('scaled') 
plt.show()

# %% [markdown]
# # 눈금 간격 제어

# %%
import matplotlib.ticker as ticker

x = np.linspace(-15, 15, 1024)
y = np.sinc(x)

ax = plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(5)) # 괄호의 숫자는 간격크기를 의미
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))

ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.1))

#set~ 어쩌구가 어려울 수 있는데 matplolib 사이트에 들어가서 찾아 공부하면 이해가 좀더 될 듯..

plt.grid(True, which = 'minor') # which = 'minor' / 'major' / 'both'
plt.plot(x, y)
plt.show()

# %% [markdown]
# # 눈금 레이블

# %%
import matplotlib.ticker as ticker

name_list = ('one', 'two', 'three', 'four', 'five')
value_list = np.random.randint(0, 99, size = len(name_list))
pos_list = np.arange(len(name_list))

plt.bar(pos_list, value_list, color = '0.75', align = 'center')

plt.xticks(pos_list, name_list) # 일반적인 케이스

plt.show()

# %%
import matplotlib.ticker as ticker
import datetime

start_data = datetime.datetime(1998, 1, 1)

def make_label(value, pos):
    time = start_data + datetime.timedelta(days = 365 * value)
    return time.strftime('%b %y')

ax = plt.axes()
ax.xaxis.set_major_formatter(ticker.FuncFormatter(make_label)) # FuncFomatter에 함수적용 가능

x = np.linspace(0, 1, 256)
plt.plot(x, np.exp(-10 * x), c = 'k')
plt.plot(x, np.exp(-5 * x), c = 'k', ls = '--')

labels = ax.get_xticklabels()
plt.setp(labels, rotation = 30)
plt.show()

# %% [markdown]
# # 그림 범위 지정

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r") #이런식으로 파라미터를 줄여서 알고 있으면 좋음

plt.xlim(0, 50)
plt.ylim(-10, 30)

plt.show()

# %% [markdown]
# # 부그림 삽입

# %%
x = np.linspace(-6, 6, 1024)
y = np.sinc(x)

x_detail = np.linspace(-3, 3, 1024)
y_detail = np.sinc(x_detail)

plt.plot(x, y, c = 'k')

sub_axes = plt.axes([.6, .6, .4, .25])  
# 전체 그림의 왼쪽하단코너(0,0), 오른쪽상단코너(1,1) 라고 하면 // .6, .6 은 작은 그래프 왼쪽하단코너의 좌표 / .4, .25 는 크기
sub_axes.plot(x_detail, y_detail, c = 'k')

#plt.setp(sub_axes) -> 책에 써있는데 왜하는지 모르겠음

plt.show()

# %% [markdown]
# # 극좌표 사용

# %%
T = np.linspace(0, 2*np.pi, 1024)

plt.axes(polar = True)
plt.plot(T, 1. + .25 * np.sin(16 * T), c = 'k')
plt.show()

# %% [markdown]
# # PNG 사진 파일 생성

# %%
x = np.linspace(-10, 10, 1024)
y = np.sinc(x)

plt.plot(x, y)

plt.savefig('sinc.png', c = 'k')
